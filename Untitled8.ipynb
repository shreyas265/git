# %%
import matplotlib.pyplot as plt
x1=[1,2,3]
y1=[2,4,2]
plt.plot(x1,y1,label="line 1")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('line')
plt.legend()
plt.show()

# %%
left=[1,3,5,7,9,11,13]
height=[10,24,36,40,5,17,8]
label=['sun', 'mon', 'tue', 'wed', 'thurs', 'fri', 'sat']
plt.bar(left,height,tick_label=label,
       width=1.0, color=['blue', 'green'])
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()

# %%
ages=[12,5,72,40,30,56,50,45,43,40,44,
     50,17,13,27,18,90,77,62,88,20,40]
range=(0,100)
bins=10
plt.hist(ages,bins,range,color='pink',
        histtype='bar',rwidth=0.8)
plt.xlabel('age')
plt.ylabel('No.of people')
plt.title('Histogram')
plt.show()

# %%
ages=[5,45,35,95,25,65,45,75,12,21,32,
      14,43,52,41,18,20,80,45,65,24,55]
range=(0,100)
bins=10
plt.hist(ages,bins,range,color='maroon',
        histtype='bar',rwidth=0.8)
plt.xlabel('age')
plt.ylabel('No.of people')
plt.title('Histogram')
plt.show()

# %%
activities=['sunday', 'monday', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday']
slices=[3,7,8,6,6,4,5]
colors=['pink', 'cyan', 'yellow', 'green', 'orange', 'blue', 'red']
plt.pie(slices,labels=activities,colors=colors,
       startangles=180,shadow=true,explore=(0,0,0.1,0,0,0,0),
       radius=1.2,autopct='%1.1f%%')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-f68f616c0ff0> in <module>()
#       3 colors=['pink', 'cyan', 'yellow', 'green', 'orange', 'blue', 'red']
#       4 plt.pie(slices,labels=activities,colors=colors,
# ----> 5        startangles=180,shadow=true,explore=(0,0,0.1,0,0,0,0),
#       6        radius=1.2,autopct='%1.1f%%')
#       7 plt.legend()
#
# NameError: name 'true' is not defined
